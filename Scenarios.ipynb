# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from mpl_toolkits.axes_grid1 import make_axes_locatable
import glob
import seaborn as sns
from scipy.interpolate import interp1d
# %matplotlib notebook
# %matplotlib inline

import geopandas
from geopandas.tools import sjoin
import geoplot as gplt
import geoplot.crs as gcrs

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Importing current scenario data (no recovery)

# %%
BaseCase_Scenario_tonperyear = pd.read_csv('Data/RecoverablePFlows_Summary.csv', sep=",", header=0)
BaseCase_Scenario_tonperyear
# Out:
#    Agriculture_Out_Manure  Agriculture_Out_CropResidues  Agriculture_Out_Plegacy  Agriculture_Out_SlaughterhouseWaste  Agriculture_Out_GNF  Urban_Out_WWTP_Disposals  Urban_Out_WWTP_Releases  Urban_Out_MunicipalSolidWaste  Urban_Out_SepticSystems  Industrial_Out_Steel  Industrial_Out_Forestry  Industrial_Out_Chemicals  Industrial_Out_CatDogFood
# 0                 30583.2                       32545.3                     9179                               3796.6                105.7                      5491                    900.6                           1767                     1445                  6700                      NaN                       NaN                        506

# %% [markdown]
# # Importing technologies data

# %%
P_RecoveryTechs_Cost = pd.read_csv('Data/PRecoveryTechsCost.csv', sep=",", header=0)
P_RecoveryTechs_Cost
# Out:
#          Sector                                 Flow                                       Technology                                      Type  P recovery potential\n(% related to influent)  P recovery cost (EUR/kg P recovered)  P recovery cost with extra costs (EUR/kg P recovered)  TRL                       P recovery cost available?                                           Ref tech                                           Ref cost
# 0   Agriculture                Manure (liquid phase)                                        Multiform                                  Struvite                                           60.0                                  24.4                                               24.4        9                                              Yes  Absorbed by Ostara: https://www.newtrient.com/...  Edgar, for instance https://www.sciencedirect....
# ...

# %% [markdown]
# # Scenario 1: Commercial technologies
#
# This scenario allows P recovery from all streams except steel production, altough some of them at a highcost (WWTP sludge, manure solid, slaughterhouse solid, organic MSW)

# %% [markdown]
# # Scenario 1.1: Commercial technologies
#
# Consider the use of EBPR and the not use of EBPR in WWTPs

# %% [markdown]
# # Scenario 2: Technologies expected to be available in the near future
#
# These techs would allow a derease of P recovery cost from asshes (WWTP sludge, manure solid, slaughterhouse solid, organic MSW)

# %% [markdown]
# # Scenario 3: Technologies which feasibility is uncertain
#
# This scenario adds in the system the recovery of P from steel
