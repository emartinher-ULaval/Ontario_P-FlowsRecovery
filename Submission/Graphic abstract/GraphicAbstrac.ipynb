# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from mpl_toolkits.axes_grid1 import make_axes_locatable
import glob
import seaborn as sns
import networkx as nx
# %matplotlib notebook
# %matplotlib inline

import geopandas
from geopandas.tools import sjoin
# import geoplot as gplt
# import geoplot.crs as gcrs

# import contextily as cx

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
Boundaries  = geopandas.GeoDataFrame.from_file('Soil Landscapes/Boundaries/lpr_000b16a_e/lpr_000b16a_e.shp')
Boundaries = Boundaries.to_crs('epsg:3857') #3978

# %%
fig, ax = plt.subplots(1, 1, figsize=(7.2, 7))#, gridspec_kw={'width_ratios': [1, 1]})

Boundaries[Boundaries['PRNAME']=='Ontario'].plot(ax=ax,facecolor="grey", alpha=1, edgecolor='grey', linewidth=0.5)

ax.set_axis_off()

plt.savefig('OntarioShape'+'.pdf', bbox_inches='tight',)
plt.savefig('OntarioShape'+'.svg', bbox_inches='tight',)
plt.savefig('OntarioShape'+'.eps', bbox_inches='tight',)
